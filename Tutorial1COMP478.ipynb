# %% [markdown]
# <a href="https://colab.research.google.com/github/myconcordia/COMP478/blob/main/Tutorial1COMP478.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import Python modules**

# %%
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow
import os

print(cv2.__version__, cv2.__spec__)
#print(cv2.getBuildInformation())
# Out:
# 4.6.0 ModuleSpec(name='cv2', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7efee474de50>, origin='/usr/local/lib/python3.8/dist-packages/cv2/__init__.py', submodule_search_locations=['/usr/local/lib/python3.8/dist-packages/cv2'])

# %% [markdown]
# **Mount Google Drive: First mount and authenticate yourself with the following code**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
#Second change your current folder to point working folder My Drive
os.chdir("/content/drive/My Drive/")
os.listdir()

# %% [markdown]
# **Read and display an image**

# %%
I = cv2.imread('./images/fruits.png')
J = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)
print('Image size:', I.shape)
print('Image size:', J.shape)

#color images
cv2_imshow(I)

#grayscale image
cv2_imshow(J)
# Out:
# Image size: (512, 512, 3)
# Image size: (512, 512, 3)
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7EFED60B2EB0>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7EFED60B2DC0>

# %% [markdown]
# **Using Matplotlib**

# %%
I = cv2.imread('./images/cat.png')
Ic = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)
print('Image size:', I.shape)
plt.imshow(Ic)
#plt.axis('off')  # to hide tick values on X and Y axis
plt.show()
J = cv2.cvtColor(I, cv2.COLOR_BGR2GRAY)
print('Image size:', J.shape)
plt.imshow(J, cmap ='gray')
# Out:
# Image size: (512, 512, 3)
# Image size: (512, 512)

# %%
# Resize image
resized = cv2.resize(I, (256, 256), interpolation = cv2.INTER_AREA)
print('Resized Dimensions : ',resized.shape)
#cv2.imwrite('cat.png', resized)
# Out:
# Resized Dimensions :  (256, 256, 3)

# %%
##OpenCV follows BGR order, while plt follows RGB order
I = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)
B,G,R = cv2.split(I)       # get Blue,Green,Red
#I = cv2.merge([R,G,B])     # switch it to RGB
plt.figure()
plt.subplot(121), plt.imshow(I), plt.title('Color image ')
#plt.axis('off')
plt.subplot(122), plt.imshow(J, cmap ='gray'), plt.title('Grayscale image')
#plt.axis('off')
plt.tight_layout()
plt.show()

# %%
plt.figure('RGB image channels')
plt.subplot(131), plt.imshow(R, cmap ='gray'), plt.axis('off')
plt.subplot(132), plt.imshow(G, cmap ='gray'), plt.axis('off')
plt.subplot(133), plt.imshow(B, cmap ='gray'), plt.axis('off')
plt.tight_layout()
plt.show()

# %%
#converting image to HSV format
HSV = cv2.cvtColor(I,cv2.COLOR_BGR2HSV)
H,S,V = cv2.split(HSV)
plt.figure('HSV image channels')
plt.subplot(131), plt.imshow(H, cmap ='gray'), plt.axis('off')
plt.subplot(132), plt.imshow(S, cmap ='gray'), plt.axis('off')
plt.subplot(133), plt.imshow(V, cmap ='gray'), plt.axis('off')
plt.tight_layout()
plt.show()

# %%
#Encoding images in HSV and HLS space
I = cv2.imread('./images/lenacolor256.png')
J = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)
I_hsv = cv2.cvtColor(I, cv2.COLOR_BGR2HSV)
plt.figure()
plt.subplot(121), plt.imshow(J), plt.axis('off')
plt.subplot(122), plt.imshow(I_hsv), plt.axis('off')
plt.tight_layout()
plt.show()
